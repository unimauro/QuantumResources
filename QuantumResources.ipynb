# %% [markdown]
# <a href="https://colab.research.google.com/github/unimauro/QuantumResources/blob/master/QuantumResources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 4.5MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=a1b6c08df5b2ed83928981b31f49273be62b64d09869ab2809bf4e4f4a4632e6
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
pip install urllib3

# %%
import urllib3
http = urllib3.PoolManager()
res = http.request('GET', 'https://b-ok.lat/s/quantum%20computer?order=year')
# Out:
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
print(res)

# %%
print(res.data)
# Out:
# b'\n<!DOCTYPE html>\n<html>\n    <head>\n        <title>quantum computer: free download. Ebooks library. On-line books store on Z-Library</title>\r\n<base href="/">\r\n\r\n                        <meta charset="utf-8">\t\t                       \r\n                        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\r\n                        <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n                        <meta name="viewport" content="width=device-width, initial-scale=1">\r\n                        <meta name="title" content="quantum computer: free download. Ebooks library. On-line books store on Z-Library">\r\n\t\t\t<meta name="description" content="quantum computer: free download. Ebooks library. On-line books store on Z-Library | B\xe2\x80\x93OK. Download books for free. Find books">\r\n\t\t\t<meta name="robots" content="index,all">\r\n\t\t\t<meta name="distribution" content="global">\r\n\t\t\t<meta http-equiv="cache-control" content="no-
# ...

# %%
print(len(res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')))
# Out:
# 51

# %%
print(res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')[45])
# Out:
# " data-book_id="4986950" itemscope itemtype="http://schema.org/Book">
#     <div>
#         <div class="counter">45</div>
#         <table style="width:100%; height:100%;" class="resItemTable">
#             <tr>
#                 <td class="itemCover">
#                     <div class="checkBookDownloaded itemCoverWrapper" data-book_id="4986950">
#                         <a href="/book/4986950/5ef931"><img class="cover lazy" alt="" data-src="https://static.zlibcdn.com/covers100/books/f6/e5/69/f6e5691ee60ad7e48b9df76f0ed2a531.jpg" data-srcset="https://static.zlibcdn.com/covers100/books/f6/e5/69/f6e5691ee60ad7e48b9df76f0ed2a531.jpg 1x, https://static.zlibcdn.com/covers200/books/f6/e5/69/f6e5691ee60ad7e48b9df76f0ed2a531.jpg 2x" /></a>
#                     </div>
#                 </td>
#                 <td style="vertical-align: top;">
#                     <table style="width:100%;height:100%;">
#                         <tr>
#                             <td>
# ...

# %%
print(res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')[1].split('text-decoration')[1].split('</a')[0].split('>')[1])
# Out:
# Cryptography Apocalypse: Preparing For The Day When Quantum Computing Breaks Today’s Crypto

# %%
for i in range(1,51):
  print(res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')[i].split('bookProperty property_year')[1].split('property_value')[1].split('>')[1].split('<')[0]+'-::-'+res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')[i].split('text-decoration')[1].split('</a')[0].split('>')[1])+'-::-'+res.data.decode('utf-8').split('resItemBox resItemBoxBooks exactMatch')[i].split()
# Out:
# 2020-Cryptography Apocalypse: Preparing For The Day When Quantum Computing Breaks Today’s Crypto
# 2020-Quantum Image Processing
# 2020-Analysis and Design of Next-Generation Software Architectures: 5G, IoT, Blockchain, and Quantum Computing
# 2020-Quantum Computing and Blockchain in Business: Exploring the applications, challenges, and collision of quantum computing and blockchain
# 2020-Quantum Computing and Blockchain in Business: Exploring the applications, challenges, and collision of quantum computing and blockchain
# 2019-Practical Quantum Computing for Developers: Programming Quantum Rigs in the Cloud using Python, Quantum Assembly Language and IBM QExperience
# 2019-Computational Methods to Study the Structure and Dynamics of Biomolecules and Biomolecular Processes: From Bioinformatics to Molecular Quantum Mechanics
# 2019-Computational Quantum Mechanics
# ...
